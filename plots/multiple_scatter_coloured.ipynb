# %%
import pandas as pd
from datetime import datetime
import pylab as plt
import numpy as np
import glob
import os
import sys
import matplotlib

# %%
x = list(range(10))
print(len(x))
c=np.full((1,len(x)),4)
print(c.shape)
# Out:
# 10
# (1, 10)

# %%
fig = plt.figure(dpi=100)
ax = plt.axes()

labels=["-90_-60","-60_-30","-30_0","0_30","30_60","60_90"]
x = list(range(10))

cmap = matplotlib.cm.get_cmap('viridis')

for i in range(6):
    ax.scatter(np.multiply(i,x),x,c=[cmap(i/6)],label=f'{labels[i]}')

#ax.set_xlim(1600,2000)
plt.legend()
plt.xlabel('[CH4] / ppb')
plt.ylabel('Altitude / m')
plt.title(f'CH4 Profile')
# Out:
# Text(0.5, 1.0, 'CH4 Profile')
