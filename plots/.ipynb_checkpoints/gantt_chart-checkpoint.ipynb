# %%
import pylab as plt
#import matplotlib.pyplot as plt

# %%
fig = plt.figure(dpi=150)
ax = plt.axes()

y_tick_labs = ['Data analysis', 'Model running', 'Set up experiments']
x_tick_labs = ['Jul 20','Jul 21','Jul 22','Jul 23']

ax.set_yticks([15, 25, 35]) 
ax.set_yticklabels(y_tick_labs)

ax.set_xticks([0,12, 24, 36]) 
ax.set_xticklabels(x_tick_labs)

#define time range of tasks
ax.broken_barh([(0, 3)], (30, 9),facecolors='lightblue')
ax.broken_barh([(3, 9)], (20, 9),facecolors='lightblue') #why does this not work
ax.broken_barh([(9, 18)], (10, 9),facecolors='lightblue') 


ax.set_ylim(0, 50)
ax.set_xlim(0, 36) 
#ax.set_xlabel('Time') 
#ax.set_ylabel('Task')
#plt.savefig("gantt1.png")
# Out:
# (0, 36)
